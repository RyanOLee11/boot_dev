# %%
import pandas as pd
import plotly.graph_objects as go
import nfl_data_py as nfl

# %%
## get the total for the season for each player

year_list = [2024]
df = nfl.import_seasonal_data(year_list)
id_df = nfl.import_ids()
id_df = id_df[['gsis_id','name']]
df = pd.merge(df,  
                    id_df,  
                    left_on = 'player_id',
                    right_on = 'gsis_id',
                    how ='left')
df
# Out:
#       player_id  season season_type  completions  attempts  passing_yards  \
# 0    00-0023459    2024         REG          368       584         3897.0
# 1    00-0024243    2024         REG            0         0            0.0
# 2    00-0026158    2024         REG          162       248         1761.0
# 3    00-0026300    2024         REG            2         3           17.0
# 4    00-0026498    2024         REG          340       517         3762.0
# ..          ...     ...         ...          ...       ...            ...
# 602  00-0039917    2024         REG           61       105          775.0
# 603  00-0039918    2024         REG          351       562         3541.0
# 604  00-0039919    2024         REG            0         0            0.0
# 605  00-0039920    2024         REG            0         0            0.0
# 606  00-0039921    2024         REG            0         0            0.0
#
#      passing_tds  interceptions  sacks  sack_yards  ...     ry_sh  rtd_sh  \
# ...

# %%
## get the weekly data for each player
df = nfl.import_weekly_data([2024])
df
# Out:
# Downcasting floats.
#        player_id player_name player_display_name position position_group  \
# 0     00-0023459   A.Rodgers       Aaron Rodgers       QB             QB
# 1     00-0023459   A.Rodgers       Aaron Rodgers       QB             QB
# 2     00-0023459   A.Rodgers       Aaron Rodgers       QB             QB
# 3     00-0023459   A.Rodgers       Aaron Rodgers       QB             QB
# 4     00-0023459   A.Rodgers       Aaron Rodgers       QB             QB
# ...          ...         ...                 ...      ...            ...
# 5592  00-0039921    T.Benson         Trey Benson       RB             RB
# 5593  00-0039921    T.Benson         Trey Benson       RB             RB
# 5594  00-0039921    T.Benson         Trey Benson       RB             RB
# 5595  00-0039921    T.Benson         Trey Benson       RB             RB
# 5596  00-0039921    T.Benson         Trey Benson       RB             RB
#
# ...

# %%
df = nfl.import_ngs_data('passing', [2024])

df
# Out:
#       season season_type  week player_display_name player_position team_abbr  \
# 4714    2024         REG     0         Jalen Hurts              QB       PHI
# 4715    2024         REG     0         Sam Darnold              QB       MIN
# 4716    2024         REG     0      Deshaun Watson              QB       CLE
# 4717    2024         REG     0        Kirk Cousins              QB       ATL
# 4718    2024         REG     0     Aidan O'Connell              QB        LV
# ...      ...         ...   ...                 ...             ...       ...
# 5323    2024        POST    21     Patrick Mahomes              QB        KC
# 5324    2024        POST    21      Jayden Daniels              QB       WAS
# 5325    2024        POST    21          Josh Allen              QB       BUF
# 5326    2024        POST    23     Patrick Mahomes              QB        KC
# 5327    2024        POST    23         Jalen Hurts              QB       PHI
#
# ...

# %%
df = nfl.import_ftn_data([2024])
# print( df.columns )
df
# Out:
# Downcasting floats.
#        ftn_game_id nflverse_game_id  season  week  ftn_play_id  \
# 0             6449   2024_01_BAL_KC    2024     1      1057995
# 1             6449   2024_01_BAL_KC    2024     1      1057996
# 2             6449   2024_01_BAL_KC    2024     1      1057997
# 3             6449   2024_01_BAL_KC    2024     1      1057998
# 4             6449   2024_01_BAL_KC    2024     1      1057999
# ...            ...              ...     ...   ...          ...
# 48026         6733   2024_22_KC_PHI    2024    22      1106021
# 48027         6733   2024_22_KC_PHI    2024    22      1106022
# 48028         6733   2024_22_KC_PHI    2024    22      1106023
# 48029         6733   2024_22_KC_PHI    2024    22      1106024
# 48030         6733   2024_22_KC_PHI    2024    22      1106025
#
#        nflverse_play_id starting_hash qb_location  n_offense_backfield  \
# 0                    43             0           0                    0
# ...

# %%
nfl.see_pbp_cols()
# Out:
# Index(['play_id', 'game_id', 'old_game_id', 'home_team', 'away_team',
#        'season_type', 'week', 'posteam', 'posteam_type', 'defteam',
#        ...
#        'out_of_bounds', 'home_opening_kickoff', 'qb_epa', 'xyac_epa',
#        'xyac_mean_yardage', 'xyac_median_yardage', 'xyac_success', 'xyac_fd',
#        'xpass', 'pass_oe'],
#       dtype='object', length=372)
